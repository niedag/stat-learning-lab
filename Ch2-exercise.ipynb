# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Data
X1 = [0, 2, 0, 0, -1, 1]
X2 = [3, 0, 1, 1, 0, 1]
X3 = [0, 0, 3, 2, 1, 1]
Y = ["Red", "Red", "Red", "Green", "Green", "Red"]

# Convert colors to numbers for plotting
colors = {"Red": "r", "Green": "g"}
Y_colors = [colors[y] for y in Y]

# Create 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X1, X2, X3, c=Y_colors)

# Set labels
ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('X3')

plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.neighbors import NearestNeighbors
import numpy as np

# Data
X1 = [0, 2, 0, 0, -1, 1]
X2 = [3, 0, 1, 1, 0, 1]
X3 = [0, 0, 3, 2, 1, 1]
Y = ["Red", "Red", "Red", "Green", "Green", "Red"]

# Convert colors to numbers for plotting
colors = {"Red": "r", "Green": "g"}
Y_colors = [colors[y] for y in Y]

# Observation numbers
obs_numbers = range(1, len(X1) + 1)

# Create 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot each point and annotate with observation number
for i, (x1, x2, x3) in enumerate(zip(X1, X2, X3)):
    ax.scatter(x1, x2, x3, c=Y_colors[i], label=f'Obs {obs_numbers[i]}')
    ax.text(x1, x2, x3, f'  Obs {obs_numbers[i]}', None)

# Set labels
ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('X3')

# Find nearest neighbors
X = np.array(list(zip(X1, X2, X3)))
k = 1
nbrs = NearestNeighbors(n_neighbors=k, algorithm='auto').fit(X)
distances, indices = nbrs.kneighbors(X)

# Plot the origin point (0, 0, 0)
ax.scatter(0, 0, 0, c='b', marker='o', label='Origin (0, 0, 0)')

# Draw lines connecting the origin to its nearest neighbor
for ind in indices[0]:
    ax.plot([0, X1[ind]], [0, X2[ind]], [0, X3[ind]], 'k--', alpha=0.5)

plt.legend()
plt.show()

# %%
# Finding the Euclidean distance between the test point and an observation

import numpy as np

X1 = [0, 2, 0, 0, -1, 1]
X2 = [3, 0, 1, 1, 0, 1]
X3 = [0, 0, 3, 2, 1, 1]
Y = ["Red", "Red", "Red", "Green", "Green", "Red"]

rangeX1 = range(0, len(X1))

for i in rangeX1:
    p1 = np.array([x1.i],x2[i],x3[i]])
    test_p = np.array([0,0,0])
    
    euclidean_distance = np.linalg.norm(p1 - test_p)
    print(euclidean_distance)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 13
#      10 rangeX1 = range(0, len(X1))
#      12 for i in rangeX1:
# ---> 13     p1 = np.array([x1[i],x2[i],x3[i]])
#      14     test_p = np.array([0,0,0])
#      16     euclidean_distance = np.linalg.norm(p1 - test_p)
#
# TypeError: 'int' object is not subscriptable
