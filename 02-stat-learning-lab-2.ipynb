# %%
# %run start.py
# Out:
# Your favorite libraries have been loaded.

# %%
# Loading Data

Auto = pd.read_csv('./data-sets/Auto.csv')
Auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
# Creating a whitespace-delimited version of the data 
Auto = pd.read_csv('./data-sets/Auto.data', delim_whitespace=True)
Auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0      130.0  3504.0          12.0    70
# 1    15.0          8         350.0      165.0  3693.0          11.5    70
# 2    18.0          8         318.0      150.0  3436.0          11.0    70
# 3    16.0          8         304.0      150.0  3433.0          12.0    70
# 4    17.0          8         302.0      140.0  3449.0          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0      86.00  2790.0          15.6    82
# 393  44.0          4          97.0      52.00  2130.0          24.6    82
# 394  32.0          4         135.0      84.00  2295.0          11.6    82
# 395  28.0          4         120.0      79.00  2625.0          18.6    82
# 396  31.0          4         119.0      82.00  2720.0          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
Auto['horsepower']
# dtype is object!!! Data was interpreted as strings
# Out:
# 0      130.0
# 1      165.0
# 2      150.0
# 3      150.0
# 4      140.0
#        ...
# 392    86.00
# 393    52.00
# 394    84.00
# 395    79.00
# 396    82.00
# Name: horsepower, Length: 397, dtype: object

# %%
np.unique(Auto['horsepower'])
# seeing the unique values, we can see that they're stored in '' char format
# Out:
# array(['100.0', '102.0', '103.0', '105.0', '107.0', '108.0', '110.0',
#        '112.0', '113.0', '115.0', '116.0', '120.0', '122.0', '125.0',
#        '129.0', '130.0', '132.0', '133.0', '135.0', '137.0', '138.0',
#        '139.0', '140.0', '142.0', '145.0', '148.0', '149.0', '150.0',
#        '152.0', '153.0', '155.0', '158.0', '160.0', '165.0', '167.0',
#        '170.0', '175.0', '180.0', '190.0', '193.0', '198.0', '200.0',
#        '208.0', '210.0', '215.0', '220.0', '225.0', '230.0', '46.00',
#        '48.00', '49.00', '52.00', '53.00', '54.00', '58.00', '60.00',
#        '61.00', '62.00', '63.00', '64.00', '65.00', '66.00', '67.00',
#        '68.00', '69.00', '70.00', '71.00', '72.00', '74.00', '75.00',
#        '76.00', '77.00', '78.00', '79.00', '80.00', '81.00', '82.00',
#        '83.00', '84.00', '85.00', '86.00', '87.00', '88.00', '89.00',
#        '90.00', '91.00', '92.00', '93.00', '94.00', '95.00', '96.00',
#        '97.00', '98.00', '?'], dtype=object)

# %%
Auto = pd.read_csv('./data-sets/Auto.data',
                   na_values=['?'],
                   delim_whitespace=True)
Auto['horsepower'].sum()
# Out:
# 40952.0

# %%
Auto.shape # the dimensions of Auto, there are 397 observations and 9 factors/cols
# Out:
# (397, 9)

# %%
Auto_new = Auto.dropna()
Auto_new.shape 
# Looks like there were 5 observations with blank values
# Out:
# (392, 9)

# %%
pd.read_csv?
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#     *,
#     sep: 'str | None | lib.NoDefault' = <no_default>,
#     delimiter: 'str | None | lib.NoDefault' = None,
#     header: "int | Sequence[int] | None | Literal['infer']" = 'infer',
#     names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>,
#     index_col: 'IndexLabel | Literal[False] | None' = None,
#     usecols=None,
#     squeeze: 'bool | None' = None,
#     prefix: 'str | lib.NoDefault' = <no_default>,
#     mangle_dupe_cols: 'bool' = True,
#     dtype: 'DtypeArg | None' = None,
#     engine: 'CSVEngine | None' = None,
#     converters=None,
#     true_values=None,
#     false_values=None,
#     skipinitialspace: 'bool' = False,
#     skiprows=None,
#     skipfooter: 'int' = 0,
#     nrows: 'int | None' = None,
#     na_values=None,
#     keep_default_na: 'bool' = True,
#     na_filter: 'bool' = True,
#     verbose: 'bool' = False,
# ...

# %%
Auto.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'origin', 'name'],
#       dtype='object')

# %%
Auto[:3] # first argument to [] is always to rows
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0  3504.0          12.0    70
# 1  15.0          8         350.0       165.0  3693.0          11.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320

# %%
# Using Booleans to subset the rows

idx_80 = Auto['year'] > 80
Auto[idx_80]
# Showing all cars past greater than the year 1980 - from 1981
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 338  27.2          4         135.0        84.0  2490.0          15.7    81
# 339  26.6          4         151.0        84.0  2635.0          16.4    81
# 340  25.8          4         156.0        92.0  2620.0          14.4    81
# 341  23.5          6         173.0       110.0  2725.0          12.6    81
# 342  30.0          4         135.0        84.0  2385.0          12.9    81
# 343  39.1          4          79.0        58.0  1755.0          16.9    81
# 344  39.0          4          86.0        64.0  1875.0          16.4    81
# 345  35.1          4          81.0        60.0  1760.0          16.1    81
# 346  32.3          4          97.0        67.0  2065.0          17.8    81
# 347  37.0          4          85.0        65.0  1975.0          19.4    81
# 348  37.7          4          89.0        62.0  2050.0          17.3    81
# ...

# %%
Auto[['mpg','horsepower']]
# Only data from two columns
# Out:
#       mpg  horsepower
# 0    18.0       130.0
# 1    15.0       165.0
# 2    18.0       150.0
# 3    16.0       150.0
# 4    17.0       140.0
# ..    ...         ...
# 392  27.0        86.0
# 393  44.0        52.0
# 394  32.0        84.0
# 395  28.0        79.0
# 396  31.0        82.0
#
# [397 rows x 2 columns]

# %%
Auto.index
# Out:
# RangeIndex(start=0, stop=397, step=1)

# %%
Auto_re = Auto.set_index('name')
Auto_re
# Renames all the indexes to be the name of the car model
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0  3504.0
# buick skylark 320          15.0          8         350.0       165.0  3693.0
# plymouth satellite         18.0          8         318.0       150.0  3436.0
# amc rebel sst              16.0          8         304.0       150.0  3433.0
# ford torino                17.0          8         302.0       140.0  3449.0
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0  2790.0
# vw pickup                  44.0          4          97.0        52.0  2130.0
# dodge rampage              32.0          4         135.0        84.0  2295.0
# ford ranger                28.0          4         120.0        79.0  2625.0
# chevy s-10                 31.0          4         119.0        82.0  2720.0
#
# ...

# %%
Auto_re.columns # Name column no longer exists as a factor
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'origin'],
#       dtype='object')

# %%
rows = ['amc rebel sst','ford torino']
rows
# Out:
# ['amc rebel sst', 'ford torino']

# %%
Auto_re.loc[rows]
# Out:
#                 mpg  cylinders  displacement  horsepower  weight  \
# name
# amc rebel sst  16.0          8         304.0       150.0  3433.0
# ford torino    17.0          8         302.0       140.0  3449.0
#
#                acceleration  year  origin
# name
# amc rebel sst          12.0    70       1
# ford torino            10.5    70       1

# %%
Auto_re.iloc[[3,4]]
# iloc looks up by index
# Out:
#                 mpg  cylinders  displacement  horsepower  weight  \
# name
# amc rebel sst  16.0          8         304.0       150.0  3433.0
# ford torino    17.0          8         302.0       140.0  3449.0
#
#                acceleration  year  origin
# name
# amc rebel sst          12.0    70       1
# ford torino            10.5    70       1

# %%
Auto_re.iloc[[3,4,5,6,7,8]]
# Out:
#                     mpg  cylinders  displacement  horsepower  weight  \
# name
# amc rebel sst      16.0          8         304.0       150.0  3433.0
# ford torino        17.0          8         302.0       140.0  3449.0
# ford galaxie 500   15.0          8         429.0       198.0  4341.0
# chevrolet impala   14.0          8         454.0       220.0  4354.0
# plymouth fury iii  14.0          8         440.0       215.0  4312.0
# pontiac catalina   14.0          8         455.0       225.0  4425.0
#
#                    acceleration  year  origin
# name
# amc rebel sst              12.0    70       1
# ford torino                10.5    70       1
# ford galaxie 500           10.0    70       1
# chevrolet impala            9.0    70       1
# plymouth fury iii           8.5    70       1
# pontiac catalina           10.0    70       1

# %%
Auto_re.iloc[:,[0,2,3]] # retrieve column index 0,2,3
# Out:
#                             mpg  displacement  horsepower
# name
# chevrolet chevelle malibu  18.0         307.0       130.0
# buick skylark 320          15.0         350.0       165.0
# plymouth satellite         18.0         318.0       150.0
# amc rebel sst              16.0         304.0       150.0
# ford torino                17.0         302.0       140.0
# ...                         ...           ...         ...
# ford mustang gl            27.0         140.0        86.0
# vw pickup                  44.0          97.0        52.0
# dodge rampage              32.0         135.0        84.0
# ford ranger                28.0         120.0        79.0
# chevy s-10                 31.0         119.0        82.0
#
# [397 rows x 3 columns]

# %%
Auto_re.iloc[[3,4],[0,2,3]]
# Out:
#                 mpg  displacement  horsepower
# name
# amc rebel sst  16.0         304.0       150.0
# ford torino    17.0         302.0       140.0

# %%
Auto_re.loc['ford galaxie 500', ['mpg','origin']]
# There are index entries that are not unique
# Out:
#                    mpg  origin
# name
# ford galaxie 500  15.0       1
# ford galaxie 500  14.0       1
# ford galaxie 500  14.0       1

# %%
Auto.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'origin', 'name'],
#       dtype='object')

# %%
# More with Selecting Rows and Columns

auto_mpg_30 = Auto_re['mpg'] > 30 # Take subset of cars above 30 mpg
auto_mpg_30
# Out:
# name
# chevrolet chevelle malibu    False
# buick skylark 320            False
# plymouth satellite           False
# amc rebel sst                False
# ford torino                  False
#                              ...
# ford mustang gl              False
# vw pickup                     True
# dodge rampage                 True
# ford ranger                  False
# chevy s-10                    True
# Name: mpg, Length: 397, dtype: bool

# %%
Auto_re.loc[auto_mpg_30, ['year','horsepower']]
# Out:
#                      year  horsepower
# name
# toyota corolla 1200    71        65.0
# datsun 1200            71        69.0
# datsun b210            74        67.0
# toyota corolla 1200    74        65.0
# toyota corona          74        52.0
# ...                   ...         ...
# toyota celica gt       82        96.0
# dodge charger 2.2      82        84.0
# vw pickup              82        52.0
# dodge rampage          82        84.0
# chevy s-10             82        82.0
#
# [85 rows x 2 columns]

# %%
# More concise way of taking subset 
Auto_re.loc[lambda df: df['mpg'] > 29, ['horsepower','weight']]
# Lambda call creates a function that takes a single argument and returns the response
# Out:
#                      horsepower  weight
# name
# peugeot 304                70.0  2074.0
# fiat 124b                  76.0  2065.0
# toyota corolla 1200        65.0  1773.0
# datsun 1200                69.0  1613.0
# datsun b210                67.0  1950.0
# ...                         ...     ...
# toyota celica gt           96.0  2665.0
# dodge charger 2.2          84.0  2370.0
# vw pickup                  52.0  2130.0
# dodge rampage              84.0  2295.0
# chevy s-10                 82.0  2720.0
#
# [97 rows x 2 columns]

# %%
# Suppose we want a subset of cars with mp3 > 30 and year > 80
Auto_re.loc[lambda df: (df['year'] > 80) & (df['mpg'] > 29), 
                        ['weight', 'horsepower']
]
# Out:
#                                    weight  horsepower
# name
# plymouth reliant                   2385.0        84.0
# toyota starlet                     1755.0        58.0
# plymouth champ                     1875.0        64.0
# honda civic 1300                   1760.0        60.0
# subaru                             2065.0        67.0
# datsun 210 mpg                     1975.0        65.0
# toyota tercel                      2050.0        62.0
# mazda glc 4                        1985.0        68.0
# plymouth horizon 4                 2215.0        63.0
# ford escort 4w                     2045.0        65.0
# ford escort 2h                     2380.0        65.0
# volkswagen jetta                   2190.0        74.0
# renault 18i                        2320.0         NaN
# honda prelude                      2210.0        75.0
# toyota corolla                     2350.0        75.0
# datsun 200sx                       2615.0       100.0
# ...

# %%
# For Loops

total = 0
for value in [3,2,19]:
    total += value
print('total is {0}'.format(total))
# Out:
# total is 24

# %%
total = 0
for value in [3,2,19]:
    for weight in [3,2,1]:
        total += value * weight
print('total is: {0}'.format(total))
# Out:
# total is: 144

# %%
total = 0
for value, weight in zip([2,3,19],
                         [0.2,0.3,0.5]):
    total += weight * value
print('weighted avg is: {0}'.format(total))
# Out:
# weighted avg is: 10.8

# %%
# String formatting
# Many data cleaning tasks involve manipulating and programmatically producing strings!
# Ex: we want to loop over the columns of a data frame and print the percent missing in each column

rng = np.random.default_rng(1)
A = rng.standard_normal((127,5))
M = rng.choice([0, np.nan], p = [0.8,0.2], size = A.shape)
A += M
D = pd.DataFrame(A, columns = ['food',
                               'bar',
                               'pickle',
                               'snack',
                               'popcorn'])
D[:3]
# Out:
#        food       bar    pickle     snack   popcorn
# 0  0.345584  0.821618  0.330437 -1.303157       NaN
# 1       NaN -0.536953  0.581118  0.364572  0.294132
# 2       NaN  0.546713       NaN -0.162910 -0.482119

# %%
for col in D.columns:
    template = 'Column "{0}" has {1:.2%} missing values'
    print(template.format(col, np.isnan(D[col]).mean()))

# use template.format() to replace the values {0}, {1:.2%}
# {1:.2%} - returns a floating value with 2 decimal places
# Out:
# Column "food" has 16.54% missing values
# Column "bar" has 25.98% missing values
# Column "pickle" has 29.13% missing values
# Column "snack" has 21.26% missing values
# Column "popcorn" has 22.83% missing values

# %%
# Additional basics for formatting and graphing
# Review: fig, ax values get returned as a figure var (fig) and axes (ax) from subplots call
fig, ax = subplots(figsize=(8,8))
ax.plot(Auto['horsepower'], Auto['mpg'], 'o');

# %%
# Alternative to plot(), you can use Auto.plot(). 
# Doing this, variables can be accessed by name.
ax = Auto.plot.scatter('horsepower', 'mpg');
ax.set_title('Horsepower vs. MPG')
# Out:
# Text(0.5, 1.0, 'Horsepower vs. MPG')

# %%
# Saving a figure 
fig = ax.figure
fig.savefig('horsepower_mpg.png')

# %%
# Changing the df to plot to a particular axes obj
# We place our scatter plot at index 1 (0,1,2)
fig, axes = subplots(ncols=3, figsize = (15,5))
Auto.plot.scatter('horsepower','mpg', ax = axes[1])
# Out:
# <Axes: xlabel='horsepower', ylabel='mpg'>

# %%
# Changing to use cylinders variable

Auto.cylinders.dtype
# Out:
# dtype('int64')
